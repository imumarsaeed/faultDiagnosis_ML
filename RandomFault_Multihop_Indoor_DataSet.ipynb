# %%
import os
import pandas as pd
import random
from random import randint

# %%
df = pd.read_excel(r"C:\Users\MCSL-user\Pictures\0.2_constant_FaultDiagnosis_multihop_indoor_dataset.xlsx",
                                            sheet_name='normal')
df.head()
# Out:
#     1_T1   2_T2   3_H1   4_H2   5_T1   6_T2   7_H1   8_H2   9_T1  10_T2  \
# 0  27.61  27.63  46.82  48.71  27.61  27.63  46.82  48.68  27.61  27.63
# 1  27.63  27.65  46.62  48.51  27.64  27.65  46.56  48.51  27.64  27.66
# 2  27.65  27.67  46.52  48.51  27.66  27.69  46.49  48.45  27.66  27.69
# 3  27.67  27.70  46.49  48.32  27.67  27.71  46.49  48.29  27.67  27.71
# 4  27.67  27.73  46.52  48.25  27.67  27.73  46.49  48.25  27.68  27.73
#
#    11_H1  12_H2  13_T1  14_T2  15_H1  16_H2  Label    Signal  Fault Label
# 0  46.79  48.64  27.63  27.64  46.69  48.58      0    Normal          0.0
# 1  46.56  48.55  27.65  27.66  46.52  48.55      0  Hardover          1.0
# 2  46.49  48.38  27.67  27.69  46.49  48.35      0     Drift          2.0
# 3  46.52  48.29  27.67  27.73  46.52  48.25      0     Spike          3.0
# 4  46.49  48.25  27.69  27.73  46.46  48.32      0   Erratic          4.0

# %%
# Randomly fault injected at each instance from sensor

# Sensor 1

df_faulty = df[['1_T1','3_H1']]
randomFault = df_faulty.head(300)
                                                    #random.uniform() for float number generation
randomFault_value = random.uniform(-5,5)            #random value generation
                                                    #randint() for int number generation
final_randomFault1 = randomFault_value + randomFault

print(randomFault_value)
# Out:
# -0.6241762968601385

# %%
df_faulty = df[['5_T1','7_H1']]
randomFault = df_faulty.head(300)

randomFault_value = random.uniform(-5,5)     #random value generation

final_randomFault2 = randomFault_value + randomFault

print(randomFault_value)
# Out:
# 2.893455180961709

# %%
df_faulty = df[['9_T1','11_H1']]
randomFault = df_faulty.head(300)

randomFault_value = random.uniform(-5,5)     #random value generation

final_randomFault3 = randomFault_value + randomFault

print(randomFault_value)
# Out:
# 3.05845967465479

# %%
df_faulty = df[['13_T1','15_H1']]
randomFault = df_faulty.head(300)

randomFault_value = random.uniform(-5,5)    #random value generation

final_randomFault4 = randomFault_value + randomFault

print(randomFault_value)
# Out:
# -1.4485950782485757

# %%
final_randomFault = pd.concat([final_randomFault1, final_randomFault2, final_randomFault3, final_randomFault4], axis=1)

df_normal = df[['2_T2','4_H2','6_T2','8_H2','10_T2','12_H2','14_T2','16_H2']]
finalnormal = df_normal.head(300)

finaldf = pd.concat([final_randomFault, finalnormal], axis=1)
finaldf1 = finaldf[['1_T1','2_T2','3_H1','4_H2','5_T1','6_T2','7_H1','8_H2','9_T1','10_T2','11_H1','12_H2','13_T1','14_T2','15_H1','16_H2']]

# %%
# Sensor 2

df_faulty = df[['2_T2','4_H2']]
randomFault = df_faulty.tail(300)

randomFault_value = random.uniform(-5,5)    #random value generation

final_randomFault1 = randomFault_value + randomFault

print(randomFault_value)
# Out:
# -4.465228923741434

# %%
df_faulty = df[['6_T2','8_H2']]
randomFault = df_faulty.tail(300)

randomFault_value = random.uniform(-5,5)    #random value generation

final_randomFault2 = randomFault_value + randomFault

print(randomFault_value)
# Out:
# -1.068518051624653

# %%
df_faulty = df[['10_T2','12_H2']]
randomFault = df_faulty.tail(300)

randomFault_value = random.uniform(-5,5)     #random value generation

final_randomFault3 = randomFault_value + randomFault

print(randomFault_value)
# Out:
# -0.16331372334774574

# %%
df_faulty = df[['14_T2','16_H2']]
randomFault = df_faulty.tail(300)

randomFault_value = random.uniform(-5,5)     #random value generation

final_randomFault4 = randomFault_value + randomFault

print(randomFault_value)
# Out:
# 4.690571103079124

# %%
final_randomFault = pd.concat([final_randomFault1, final_randomFault2, final_randomFault3, final_randomFault4], axis=1)

df_normal = df[['1_T1','3_H1','5_T1','7_H1','9_T1','11_H1','13_T1','15_H1']]
finalnormal = df_normal.tail(300)

finaldf = pd.concat([final_randomFault, finalnormal], axis=1)
finaldf2 = finaldf[['1_T1','2_T2','3_H1','4_H2','5_T1','6_T2','7_H1','8_H2','9_T1','10_T2','11_H1','12_H2','13_T1','14_T2','15_H1','16_H2']]

# %%
extreme_final = pd.concat([finaldf1, finaldf2])
extreme_final
# Out:
#           1_T1       2_T2       3_H1       4_H2       5_T1       6_T2  \
# 0    26.985824  27.630000  46.195824  48.710000  30.503455  27.630000
# 1    27.005824  27.650000  45.995824  48.510000  30.533455  27.650000
# 2    27.025824  27.670000  45.895824  48.510000  30.553455  27.690000
# 3    27.045824  27.700000  45.865824  48.320000  30.563455  27.710000
# 4    27.045824  27.730000  45.895824  48.250000  30.563455  27.730000
# 5    27.075824  27.740000  45.835824  48.290000  30.603455  27.730000
# 6    27.095824  27.720000  45.805824  48.320000  30.603455  27.740000
# 7    27.105824  27.760000  45.865824  48.320000  30.623455  27.770000
# 8    27.115824  27.770000  45.835824  48.290000  30.633455  27.770000
# 9    27.125824  27.790000  45.805824  48.250000  30.643455  27.810000
# 10   27.145824  27.800000  45.735824  48.220000  30.663455  27.800000
# 11   27.165824  27.800000  45.705824  48.160000  30.683455  27.810000
# ...

# %%
extreme_final.to_excel(r'C:\Users\MCSL-user\Pictures\random.xlsx', sheet_name='random')
