# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\MCSL-user\Pictures\1.0_constant_FaultDiagnosis_multihop_indoor_dataset.xlsx",
                  sheet_name='normal')
df.head()
# Out:
#     1_T1   2_T2   3_H1   4_H2   5_T1   6_T2   7_H1   8_H2   9_T1  10_T2  \
# 0  27.61  27.63  46.82  48.71  27.61  27.63  46.82  48.68  27.61  27.63
# 1  27.63  27.65  46.62  48.51  27.64  27.65  46.56  48.51  27.64  27.66
# 2  27.65  27.67  46.52  48.51  27.66  27.69  46.49  48.45  27.66  27.69
# 3  27.67  27.70  46.49  48.32  27.67  27.71  46.49  48.29  27.67  27.71
# 4  27.67  27.73  46.52  48.25  27.67  27.73  46.49  48.25  27.68  27.73
#
#    11_H1  12_H2  13_T1  14_T2  15_H1  16_H2  Label    Signal  Fault Label
# 0  46.79  48.64  27.63  27.64  46.69  48.58      0    Normal          0.0
# 1  46.56  48.55  27.65  27.66  46.52  48.55      0  Hardover          1.0
# 2  46.49  48.38  27.67  27.69  46.49  48.35      0     Drift          2.0
# 3  46.52  48.29  27.67  27.73  46.52  48.25      0     Spike          3.0
# 4  46.49  48.25  27.69  27.73  46.46  48.32      0   Erratic          4.0

# %%
erratic_valueP = 1                 # Sensor 1 values faulty
erratic_valueN = -1

df_faulty = df[['1_T1','3_H1','5_T1','7_H1']]
erratic1 = df_faulty.head(300)

df_faulty = df[['9_T1','11_H1','13_T1','15_H1']]
erratic2 = df_faulty.head(300)

final_erratic1 = erratic_valueP + erratic1
final_erratic2 = erratic_valueN + erratic2

df_normal = df[['2_T2','4_H2','6_T2','8_H2','10_T2','12_H2','14_T2','16_H2']]
finalnormal = df_normal.head(300)

finaldf = pd.concat([final_erratic1, final_erratic2, finalnormal], axis=1)
finaldf1 = finaldf[['1_T1','2_T2','3_H1','4_H2','5_T1','6_T2','7_H1','8_H2','9_T1','10_T2','11_H1','12_H2','13_T1','14_T2','15_H1','16_H2']]

#erratic.var()

# %%
erratic_valueP = 1                # Sensor 2 values faulty
erratic_valueN = -1

df_faulty = df[['2_T2','4_H2','6_T2','8_H2']]
erratic1 = df_faulty.tail(300)

df_faulty = df[['10_T2','12_H2','14_T2','16_H2']]
erratic2 = df_faulty.tail(300)

final_erratic1 = erratic_valueP + erratic1
final_erratic2 = erratic_valueN + erratic2

df_normal = df[['1_T1','3_H1','5_T1','7_H1','9_T1','11_H1','13_T1','15_H1']]
finalnormal = df_normal.tail(300)

finaldf = pd.concat([final_erratic1, final_erratic2, finalnormal], axis=1)
finaldf2 = finaldf[['1_T1','2_T2','3_H1','4_H2','5_T1','6_T2','7_H1','8_H2','9_T1','10_T2','11_H1','12_H2','13_T1','14_T2','15_H1','16_H2']]

#erratic.var()

# %%
extreme_final = pd.concat([finaldf1, finaldf2])
extreme_final
# Out:
#       1_T1   2_T2   3_H1   4_H2   5_T1   6_T2   7_H1   8_H2   9_T1  10_T2  \
# 0    28.61  27.63  47.82  48.71  28.61  27.63  47.82  48.68  26.61  27.63
# 1    28.63  27.65  47.62  48.51  28.64  27.65  47.56  48.51  26.64  27.66
# 2    28.65  27.67  47.52  48.51  28.66  27.69  47.49  48.45  26.66  27.69
# 3    28.67  27.70  47.49  48.32  28.67  27.71  47.49  48.29  26.67  27.71
# 4    28.67  27.73  47.52  48.25  28.67  27.73  47.49  48.25  26.68  27.73
# 5    28.70  27.74  47.46  48.29  28.71  27.73  47.46  48.25  26.72  27.72
# 6    28.72  27.72  47.43  48.32  28.71  27.74  47.46  48.32  26.72  27.73
# 7    28.73  27.76  47.49  48.32  28.73  27.77  47.43  48.25  26.73  27.77
# 8    28.74  27.77  47.46  48.29  28.74  27.77  47.46  48.29  26.74  27.77
# 9    28.75  27.79  47.43  48.25  28.75  27.81  47.39  48.29  26.75  27.80
# 10   28.77  27.80  47.36  48.22  28.77  27.80  47.33  48.19  26.78  27.80
# 11   28.79  27.80  47.33  48.16  28.79  27.81  47.33  48.16  26.79  27.81
# ...

# %%
extreme_final.to_excel(r'C:\Users\MCSL-user\Pictures\erratic.xlsx', sheet_name='erratic')
