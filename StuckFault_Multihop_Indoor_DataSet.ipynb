# %%
import os
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\MCSL-user\Pictures\0.2_constant_FaultDiagnosis_multihop_indoor_dataset.xlsx",
                  sheet_name='normal')
df.head()
# Out:
#     1_T1   2_T2   3_H1   4_H2   5_T1   6_T2   7_H1   8_H2   9_T1  10_T2  \
# 0  27.61  27.63  46.82  48.71  27.61  27.63  46.82  48.68  27.61  27.63
# 1  27.63  27.65  46.62  48.51  27.64  27.65  46.56  48.51  27.64  27.66
# 2  27.65  27.67  46.52  48.51  27.66  27.69  46.49  48.45  27.66  27.69
# 3  27.67  27.70  46.49  48.32  27.67  27.71  46.49  48.29  27.67  27.71
# 4  27.67  27.73  46.52  48.25  27.67  27.73  46.49  48.25  27.68  27.73
#
#    11_H1  12_H2  13_T1  14_T2  15_H1  16_H2  Label    Signal  Fault Label
# 0  46.79  48.64  27.63  27.64  46.69  48.58      0    Normal          0.0
# 1  46.56  48.55  27.65  27.66  46.52  48.55      0  Hardover          1.0
# 2  46.49  48.38  27.67  27.69  46.49  48.35      0     Drift          2.0
# 3  46.52  48.29  27.67  27.73  46.52  48.25      0     Spike          3.0
# 4  46.49  48.25  27.69  27.73  46.46  48.32      0   Erratic          4.0

# %%
df_faulty_temp = df[['1_T1']]
stuck_temp1 = df_faulty_temp.head(300)
stuck_temp1[['5_T1']] = stuck_temp1[['1_T1']]
stuck_temp1[['9_T1']] = stuck_temp1[['1_T1']]
stuck_temp1[['13_T1']] = stuck_temp1[['1_T1']]

df_faulty_humi = df[['3_H1']]
stuck_humi1 = df_faulty_humi.head(300)
stuck_humi1[['7_H1']] = stuck_humi1[['3_H1']]
stuck_humi1[['11_H1']] = stuck_humi1[['3_H1']]
stuck_humi1[['15_H1']] = stuck_humi1[['3_H1']]

df_normal = df[['2_T2','4_H2','6_T2','8_H2','10_T2','12_H2','14_T2','16_H2']]
finalnormal = df_normal.head(300)

finaldf_sensor1 = pd.concat([stuck_temp1, stuck_humi1, finalnormal], axis=1)
finaldf1 = finaldf_sensor1[['1_T1','2_T2','3_H1','4_H2','5_T1','6_T2','7_H1','8_H2','9_T1','10_T2','11_H1','12_H2','13_T1','14_T2','15_H1','16_H2']]

# %%
finaldf1.head()
# Out:
#     1_T1   2_T2   3_H1   4_H2   5_T1   6_T2   7_H1   8_H2   9_T1  10_T2  \
# 0  27.61  27.63  46.82  48.71  27.61  27.63  46.82  48.68  27.61  27.63
# 1  27.63  27.65  46.62  48.51  27.63  27.65  46.62  48.51  27.63  27.66
# 2  27.65  27.67  46.52  48.51  27.65  27.69  46.52  48.45  27.65  27.69
# 3  27.67  27.70  46.49  48.32  27.67  27.71  46.49  48.29  27.67  27.71
# 4  27.67  27.73  46.52  48.25  27.67  27.73  46.52  48.25  27.67  27.73
#
#    11_H1  12_H2  13_T1  14_T2  15_H1  16_H2
# 0  46.82  48.64  27.61  27.64  46.82  48.58
# 1  46.62  48.55  27.63  27.66  46.62  48.55
# 2  46.52  48.38  27.65  27.69  46.52  48.35
# 3  46.49  48.29  27.67  27.73  46.49  48.25
# 4  46.52  48.25  27.67  27.73  46.52  48.32

# %%
df_faulty_temp = df[['2_T2']]
stuck_temp2 = df_faulty_temp.tail(300)
stuck_temp2[['6_T2']] = stuck_temp2[['2_T2']]
stuck_temp2[['10_T2']] = stuck_temp2[['2_T2']]
stuck_temp2[['14_T2']] = stuck_temp2[['2_T2']]

df_faulty_humi = df[['4_H2']]
stuck_humi2 = df_faulty_humi.tail(300)
stuck_humi2[['8_H2']] = stuck_humi2[['4_H2']]
stuck_humi2[['12_H2']] = stuck_humi2[['4_H2']]
stuck_humi2[['16_H2']] = stuck_humi2[['4_H2']]

df_normal = df[['1_T1','3_H1','5_T1','7_H1','9_T1','11_H1','13_T1','15_H1']]
finalnormal = df_normal.tail(300)

finaldf_sensor2 = pd.concat([stuck_temp2, stuck_humi2, finalnormal], axis=1)
finaldf2 = finaldf_sensor2[['1_T1','2_T2','3_H1','4_H2','5_T1','6_T2','7_H1','8_H2','9_T1','10_T2','11_H1','12_H2','13_T1','14_T2','15_H1','16_H2']]

# %%
finaldf2.head()
# Out:
#       1_T1   2_T2   3_H1   4_H2   5_T1   6_T2   7_H1   8_H2   9_T1  10_T2  \
# 300  25.87  26.15  47.08  48.58  25.88  26.15  47.08  48.58  25.89  26.15
# 301  25.88  26.13  47.02  48.58  25.87  26.13  47.08  48.58  25.87  26.13
# 302  25.86  26.11  47.08  48.55  25.84  26.11  47.11  48.55  25.84  26.11
# 303  25.84  26.09  47.11  48.55  25.83  26.09  47.15  48.55  25.83  26.09
# 304  25.85  26.09  47.02  48.51  25.81  26.09  46.85  48.51  25.81  26.09
#
#      11_H1  12_H2  13_T1  14_T2  15_H1  16_H2
# 300  47.02  48.58  25.89  26.15  47.02  48.58
# 301  47.11  48.58  25.85  26.13  47.08  48.58
# 302  47.11  48.55  25.85  26.11  47.11  48.55
# 303  47.08  48.55  25.83  26.09  47.08  48.55
# 304  46.95  48.51  25.81  26.09  47.02  48.51

# %%
extreme_final = pd.concat([finaldf1, finaldf2])
extreme_final
# Out:
#       1_T1   2_T2   3_H1   4_H2   5_T1   6_T2   7_H1   8_H2   9_T1  10_T2  \
# 0    27.61  27.63  46.82  48.71  27.61  27.63  46.82  48.68  27.61  27.63
# 1    27.63  27.65  46.62  48.51  27.63  27.65  46.62  48.51  27.63  27.66
# 2    27.65  27.67  46.52  48.51  27.65  27.69  46.52  48.45  27.65  27.69
# 3    27.67  27.70  46.49  48.32  27.67  27.71  46.49  48.29  27.67  27.71
# 4    27.67  27.73  46.52  48.25  27.67  27.73  46.52  48.25  27.67  27.73
# 5    27.70  27.74  46.46  48.29  27.70  27.73  46.46  48.25  27.70  27.72
# 6    27.72  27.72  46.43  48.32  27.72  27.74  46.43  48.32  27.72  27.73
# 7    27.73  27.76  46.49  48.32  27.73  27.77  46.49  48.25  27.73  27.77
# 8    27.74  27.77  46.46  48.29  27.74  27.77  46.46  48.29  27.74  27.77
# 9    27.75  27.79  46.43  48.25  27.75  27.81  46.43  48.29  27.75  27.80
# 10   27.77  27.80  46.36  48.22  27.77  27.80  46.36  48.19  27.77  27.80
# 11   27.79  27.80  46.33  48.16  27.79  27.81  46.33  48.16  27.79  27.81
# ...

# %%
extreme_final.to_excel(r'C:\Users\MCSL-user\Pictures\stuck.xlsx', sheet_name='stuck')
